# %% [markdown]
# <a href="https://colab.research.google.com/github/meta-llama/llama-stack/blob/main/docs/zero_to_hero_guide/07_Agents101.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Agentic API 101
#
# This document talks about the Agentic APIs in Llama Stack. Before you begin, please ensure Llama Stack is installed and set up by following the [Getting Started Guide](https://llama-stack.readthedocs.io/en/latest/getting_started/index.html).
#
# Starting Llama 3.1 you can build agentic applications capable of:
#
# - breaking a task down and performing multi-step reasoning.
# - using tools to perform some actions
#   - built-in: the model has built-in knowledge of tools like search or code interpreter
#   - zero-shot: the model can learn to call tools using previously unseen, in-context tool definitions
# - providing system level safety protections using models like Llama Guard.
#
# An agentic app requires a few components:
# - ability to run inference on the underlying Llama series of models
# - ability to run safety checks using the Llama Guard series of models
# - ability to execute tools, including a code execution environment, and loop using the model's multi-step reasoning process
#
# All of these components are now offered by a single Llama Stack Distribution. Llama Stack defines and standardizes these components and many others that are needed to make building Generative AI applications smoother. Various implementations of these APIs are then assembled together via a **Llama Stack Distribution**.

# %% [markdown]
# ### Run Agent example
#
# Please check out examples with client SDKs to talk with the Llama Stack server in our [llama-stack-apps](https://github.com/meta-llama/llama-stack-apps) repo.
#
# In this tutorial, with the `Llama3.1-8B-Instruct` server running, we can use the following code to run a simple agent example:

# %% [markdown]
# Set up your connection parameters:

# %%
HOST = "localhost"  # Replace with your host
PORT = 5000        # Replace with your port

# %%
import os
from llama_stack_client import LlamaStackClient
from llama_stack_client.lib.agents.agent import Agent
from llama_stack_client.lib.agents.event_logger import EventLogger
from llama_stack_client.types.agent_create_params import AgentConfig

os.environ["BRAVE_SEARCH_API_KEY"] = "YOUR_SEARCH_API_KEY"

async def agent_example():
    client = LlamaStackClient(base_url=f"http://{HOST}:{PORT}")
    models_response = client.models.list()
    for model in models_response:
        if model.identifier.endswith("Instruct"):
            model_name = model.llama_model
    agent_config = AgentConfig(
        model=model_name,
        instructions="You are a helpful assistant",
        sampling_params={
            "strategy": "greedy",
            "temperature": 1.0,
            "top_p": 0.9,
        },
        tools=[
            {
                "type": "brave_search",
                "engine": "brave",
                "api_key": os.getenv("BRAVE_SEARCH_API_KEY"),
            }
        ],
        tool_choice="auto",
        tool_prompt_format="function_tag",
        input_shields=[],
        output_shields=[],
        enable_session_persistence=False,
    )

    agent = Agent(client, agent_config)
    session_id = agent.create_session("test-session")
    print(f"Created session_id={session_id} for Agent({agent.agent_id})")

    user_prompts = [
        "I am planning a trip to Switzerland, what are the top 3 places to visit?",
        "What is so special about #1?",
        "What other countries should I consider to club?",
        "What is the capital of France?",
    ]

    for prompt in user_prompts:
        response = agent.create_turn(
            messages=[
                {
                    "role": "user",
                    "content": prompt,
                }
            ],
            session_id=session_id,
        )

        async for log in EventLogger().log(response):
            log.print()


await agent_example()
# Out:
# Created session_id=0498990d-3a56-4fb6-9113-0e26f7877e98 for Agent(0d55390e-27fc-431a-b47a-88494f20e72c)
# inference> Switzerland is a beautiful country with a rich history, stunning landscapes, and vibrant culture. Here are the top 3 places to visit in Switzerland:
#
# 1. **Jungfraujoch**: Also known as the "Top of Europe," Jungfraujoch is a mountain peak located in the Swiss Alps. It's the highest train station in Europe, and from its summit, you can enjoy breathtaking views of the surrounding mountains and glaciers. The peak is covered in snow year-round, and you can even visit the Ice Palace and take a walk on the glacier.
# 2. **Lake Geneva (Lac Léman)**: Located in the western part of Switzerland, Lake Geneva is a stunning lake that offers breathtaking views, picturesque villages, and a rich history. You can take a boat tour of the lake, visit the Chillon Castle, or explore the charming towns of Montreux and Vevey.
# 3. **Interlaken**: Interlaken is a popular tourist destination located in the heart of the Swiss Alps. It's a paradise for outdoor enthusiasts, with plenty of opportunities for hiking, paragliding, canyoning, and other adventure activities. You can also take a scenic boat tour of the nearby lakes, visit the Trümmelbach Falls, or explore the charming town of Interlaken.
#
# These three places offer a great combination of natural beauty, culture, and adventure, and are a great starting point for your trip to Switzerland. Of course, there are many other amazing places to visit in Switzerland, but these three are definitely must-see destinations.
# inference> Jungfraujoch, also known as the "Top of Europe," is a unique and special destination for several reasons:
#
# 1. **Highest Train Station in Europe**: Jungfraujoch is the highest train station in Europe, located at an altitude of 3,454 meters (11,332 feet) above sea level. The train ride to the summit is an adventure in itself, with breathtaking views of the surrounding mountains and glaciers.
# 2. **Breathtaking Views**: From the summit, you can enjoy panoramic views of the surrounding mountains, glaciers, and valleys. On a clear day, you can see as far as the Black Forest in Germany and the Mont Blanc in France.
# 3. **Ice Palace**: Jungfraujoch is home to the Ice Palace, a stunning palace made entirely of ice and snow. The palace is a marvel of engineering and artistry, with intricate ice carvings and sculptures.
# 4. **Glacier Walking**: You can take a guided tour onto the glacier itself, where you can walk on the ice and learn about the glaciology and geology of the area.
# 5. **Observation Decks**: There are several observation decks and viewing platforms at Jungfraujoch, offering stunning views of the surrounding landscape.
# 6. **Snow and Ice Year-Round**: Jungfraujoch is covered in snow and ice year-round, making it a unique destination that's available to visit 365 days a year.
# 7. **Rich History**: Jungfraujoch has a rich history, dating back to the early 20th century when it was first built as a tourist destination. You can learn about the history of the mountain and the people who built the railway and infrastructure.
#
# Overall, Jungfraujoch is a unique and special destination that offers a combination of natural beauty, adventure, and cultural significance that's hard to find anywhere else.
# inference> Considering you're already planning a trip to Switzerland, here are some other countries in the region that you might want to consider visiting:
#
# 1. **Austria**: Known for its grand palaces, opera houses, and picturesque villages, Austria is a great destination for culture lovers. Don't miss the Schönbrunn Palace in Vienna and the stunning Alpine scenery.
# 2. **Germany**: Germany is a great destination for history buffs, with iconic cities like Berlin, Munich, and Dresden offering a wealth of cultural and historical attractions. Don't miss the Neuschwanstein Castle and the picturesque town of Rothenburg ob der Tauber.
# 3. **France**: France is famous for its fashion, cuisine, and romance, and is a great destination for anyone looking for a luxurious and cultural experience. Don't miss the Eiffel Tower in Paris, the French Riviera, and the picturesque towns of Provence.
# 4. **Italy**: Italy is a foodie's paradise, with delicious pasta dishes, pizza, and gelato. Don't miss the iconic cities of Rome, Florence, and Venice, and the stunning Amalfi Coast.
# 5. **Monaco**: Monaco is a tiny principality on the French Riviera, known for its casinos, yacht-lined harbor, and stunning scenery. It's a great destination for a quick and luxurious getaway.
# 6. **Liechtenstein**: Liechtenstein is a tiny country nestled between Switzerland and Austria, known for its picturesque villages, castles, and stunning Alpine scenery. It's a great destination for nature lovers and those looking for a peaceful retreat.
# 7. **Slovenia**: Slovenia is a hidden gem in Eastern Europe, with a stunning coastline, picturesque villages, and a rich cultural heritage. Don't miss the Lake Bled, the Postojna Cave Park, and the charming capital city of Ljubljana.
#
# These countries offer a mix of culture, history, natural beauty, and luxury that's hard to find anywhere else. Depending on your interests and travel style, you might want to consider visiting one or more of these countries in combination with Switzerland.
# inference> The capital of France is **Paris**. Paris is one of the most iconic and romantic cities in the world, known for its stunning architecture, art museums, fashion, and cuisine. It's a must-visit destination for anyone interested in history, culture, and romance.
#
# Some of the top attractions in Paris include:
#
# 1. The Eiffel Tower: The iconic iron lattice tower that symbolizes Paris and France.
# 2. The Louvre Museum: One of the world's largest and most famous museums, housing an impressive collection of art and artifacts from around the world.
# 3. Notre-Dame Cathedral: A beautiful and historic Catholic cathedral that dates back to the 12th century.
# 4. Montmartre: A charming and artistic neighborhood with narrow streets, charming cafes, and stunning views of the city.
# 5. The Champs-Élysées: A famous avenue lined with upscale shops, cafes, and theaters.
#
# Paris is also known for its delicious cuisine, including croissants, baguettes, cheese, and wine. Don't forget to try a classic French dish like escargots, ratatouille, or coq au vin during your visit!

# %% [markdown]
# We have come a long way from getting started to understanding the internals of Llama-Stack!
#
# Thanks for joining us on this journey. If you have questions-please feel free to open an issue. Looking forward to what you build with Open Source AI!
